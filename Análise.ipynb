# %% [markdown]
# # Análise de Dados sobre o Perfil Profissional dos Alunos do Curso de Tecnologia em Sistems para Internet Do IFRN Campus Canguaretama

# %% [markdown]
# ## 1 - Importando o banco de Dados

# %%
# Importando bibliotecas
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Informando o arquivo usado
arquivo = 'alunos.csv'

# Criando o DataFrame
dados = pd.read_csv(arquivo)

# Mostrando o conjunto de dados
dados

# Carregando o dataset
# df = pd.read_csv('alunos_tsi.csv')
# df
# Out:
#    Carimbo de data/hora                          Nome completo  \
# 0                   NaN             Gabriel Rodrigues Freitas
# 1                   NaN                Arthur Rocha Cavalcante
# 2                   NaN          Oziele Rodrigues de Oliveira
# 3                   NaN  Gilmar Thomaz Dantas Pereira da Silva
# 4                   NaN                     José Maria Soares
# 5                   NaN                 Fabiana de Souza Silva
# 6                   NaN               Otaciel da Silva RIbeiro
# 7                   NaN                 David Soares Carvalho
# 8                   NaN                        Rafael Ribeiro
# 9                   NaN                Laura Kauanne da Silva
# 10                  NaN                           Monik Gomes
# 11                  NaN                Maria ivelise da Silva
# 12                  NaN               Edson Domingos da Silva
# 13                  NaN              Edenilson Lima de Freitas
# ...

# %% [markdown]
# ## 2 - Renomear as Colunas

# %%
# Consukta as colunas do DataSet
dados.columns
# Out:
# Index(['Carimbo de data/hora', 'Nome completo', 'Data de nascimento', 'Turma',
#        'Cidade', 'A regiao em que mora', 'Ensino medio',
#        'Situação da Matricula', 'Semestres Cursando', 'Semestre Desistencia',
#        'Trabalho antes do curso', 'Modalidade trabalho antes do curso ',
#        'Soube de estagio/emprego DURANTE o curso?',
#        'Continuou trabalhando durante o curso',
#        'Modalidade trabalho durante o curso', 'Estágio duante curso',
#        'Modalidade estágio', 'Satisteito(a) com o estágio de TI',
#        'Concluiu, começou ou continuou a trabalhar apos o curso?',
#        'Modalidade Trabalhao após o curso',
#        'Area que Trabalhou/trabalha na TI', 'Areas estagio',
#        'Subáreas mais se identifica', 'Publicação acadêmica', 'Projetos',
#        'Confirmação de intercâmbio'],
#       dtype='object')

# %%
# Para renomear as colunas do DataFrame, é necessário armazenar esse "novo" DataFrame em uma variável
# Além disso, dentro da função deve-se passar para o parêmetro "columns" um dicionário, onde as chaves são os
# nomes das colunas do DataFrame e os valores os novos nomes

trocar_nomes = { 
    'Nome completo': 'Nome',  
    'Data de nascimento': 'Data_Nascimento',  
    'Turma': 'Turma', 
    'Cidade': 'Cidade',  
    'A regiao em que mora': 'Regiao',  
    'Ensino medio': 'Ensino_Medio', 
    'Situação da Matricula': 'Situação_Matricula',  
    'Semestres Cursando': 'Semestres_Cursando',  
    'Semestre Desistencia': 'Semestre_Desistencia', 
    'Trabalho antes do curso': 'Trabalho_Antes_Curso',  
    'Modalidade trabalho antes do curso': 'Modalidade_Trabalho_Antes_Curso',
    'Soube de estagio/emprego DURANTE o curso?': 'Soube_Estagio_ou_Emprego_Durante_Curso', 
    'Continuou trabalhando durante o curso': 'Continuou_Trabalhando_Durante_Curso', 
    'Modalidade trabalho durante o curso': 'Modalidade_Trabalho_Durante_Curso',  
    'Estágio duante curso': 'Estagio_Durante_Curso', 
    'Modalidade estágio': 'Modalidade_Estagio',  
    'Satisteito(a) com o estágio de TI': 'Satisfeito_Estagio_TI', 
    'Concluiu, começou ou continuou a trabalhar apos o curso?': 'Concluiu_ou_Comecou_ou_Continuou_Trabalhar_Apos_Curso', 
    'Modalidade Trabalhao após o curso': 'Modalidade_Trabalhao_Apos_curso', 
    'Area que Trabalhou/trabalha na TI': 'Area_Trabalhou_ou_Trabalha_TI',  
    'Areas estagio': 'Areas_Estagio_TI', 
    'Subáreas mais se identifica': 'Subareas_se_Identifica',  
    'Publicação acadêmica': 'Publicacao_Academica',  
    'Projetos': 'Projetos', 
    'Confirmação de intercâmbio': 'Confirmacao_Intercambio',
}

# Realizar a troca dos nomes das colunas
dados = dados.rename(columns=trocar_nomes)

# Mostrar o conjunto de dados
dados
# Out:
#    Carimbo de data/hora                                   Nome  \
# 0                   NaN             Gabriel Rodrigues Freitas
# 1                   NaN                Arthur Rocha Cavalcante
# 2                   NaN          Oziele Rodrigues de Oliveira
# 3                   NaN  Gilmar Thomaz Dantas Pereira da Silva
# 4                   NaN                     José Maria Soares
# 5                   NaN                 Fabiana de Souza Silva
# 6                   NaN               Otaciel da Silva RIbeiro
# 7                   NaN                 David Soares Carvalho
# 8                   NaN                        Rafael Ribeiro
# 9                   NaN                Laura Kauanne da Silva
# 10                  NaN                           Monik Gomes
# 11                  NaN                Maria ivelise da Silva
# 12                  NaN               Edson Domingos da Silva
# 13                  NaN              Edenilson Lima de Freitas
# ...

# %%
dados.columns
# Out:
# Index(['Carimbo de data/hora', 'Nome', 'Data_Nascimento', 'Turma', 'Cidade',
#        'Regiao', 'Ensino_Medio', 'Situação_Matricula', 'Semestres_Cursando',
#        'Semestre_Desistencia', 'Trabalho_Antes_Curso',
#        'Modalidade trabalho antes do curso ',
#        'Soube_Estagio_ou_Emprego_Durante_Curso',
#        'Continuou_Trabalhando_Durante_Curso',
#        'Modalidade_Trabalho_Durante_Curso', 'Estagio_Durante_Curso',
#        'Modalidade_Estagio', 'Satisfeito_Estagio_TI',
#        'Concluiu_ou_Comecou_ou_Continuou_Trabalhar_Apos_Curso',
#        'Modalidade_Trabalhao_Apos_curso', 'Area_Trabalhou_ou_Trabalha_TI',
#        'Areas_Estagio_TI', 'Subareas_se_Identifica', 'Publicacao_Academica',
#        'Projetos', 'Confirmacao_Intercambio'],
#       dtype='object')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 26 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Carimbo de data/hora                                   15 non-null     object
#  1   Nome                                                   50 non-null     object
#  2   Data_Nascimento                                        50 non-null     object
#  3   Turma                                                  50 non-null     object
#  4   Cidade                                                 50 non-null     object
#  5   Regiao                                                 50 non-null     object
#  6   Ensino_Medio                                           50 non-null     object
#  7   Situação_Matricula                                     50 non-null     object
# ...

# %% [markdown]
# ## 3 - Tratamento de dados

# %% [markdown]
# ## Parte 1

# %%
dados.describe().T
# Out:
#                                                    count unique  \
# Carimbo de data/hora                                  15     15
# Nome                                                  50     50
# Data_Nascimento                                       50     50
# Turma                                                 50      4
# Cidade                                                50     25
# Regiao                                                50      2
# Ensino_Medio                                          50      2
# Situação_Matricula                                    50      4
# Semestres_Cursando                                    43     10
# Semestre_Desistencia                                   8      6
# Trabalho_Antes_Curso                                  50      3
# Modalidade trabalho antes do curso                    41      3
# Soube_Estagio_ou_Emprego_Durante_Curso                50      2
# Continuou_Trabalhando_Durante_Curso                   50      5
# ...

# %%
# Excluindo coluna 'Carimbo de data/hora'
dados = dados.drop('Carimbo de data/hora', axis=1)

# %%
dados.columns
# Out:
# Index(['Nome', 'Data_Nascimento', 'Turma', 'Cidade', 'Regiao', 'Ensino_Medio',
#        'Situação_Matricula', 'Semestres_Cursando', 'Semestre_Desistencia',
#        'Trabalho_Antes_Curso', 'Modalidade trabalho antes do curso ',
#        'Soube_Estagio_ou_Emprego_Durante_Curso',
#        'Continuou_Trabalhando_Durante_Curso',
#        'Modalidade_Trabalho_Durante_Curso', 'Estagio_Durante_Curso',
#        'Modalidade_Estagio', 'Satisfeito_Estagio_TI',
#        'Concluiu_ou_Comecou_ou_Continuou_Trabalhar_Apos_Curso',
#        'Modalidade_Trabalhao_Apos_curso', 'Area_Trabalhou_ou_Trabalha_TI',
#        'Areas_Estagio_TI', 'Subareas_se_Identifica', 'Publicacao_Academica',
#        'Projetos', 'Confirmacao_Intercambio'],
#       dtype='object')

# %%
# Criar uma lista com as colunas que serão avaliadas
colunas = [
        'Nome', 'Data_Nascimento', 'Turma', 'Cidade',
       'Regiao', 'Ensino_Medio', 'Situação_Matricula', 'Semestres_Cursando',
       'Semestre_Desistencia', 'Trabalho_Antes_Curso',
       'Modalidade trabalho antes do curso ',
       'Soube_Estagio_ou_Emprego_Durante_Curso',
       'Continuou_Trabalhando_Durante_Curso',
       'Modalidade_Trabalho_Durante_Curso', 'Estagio_Durante_Curso',
       'Modalidade_Estagio', 'Satisfeito_Estagio_TI',
       'Concluiu_ou_Comecou_ou_Continuou_Trabalhar_Apos_Curso',
       'Modalidade_Trabalhao_Apos_curso', 'Area_Trabalhou_ou_Trabalha_TI',
       'Areas_Estagio_TI', 'Subareas_se_Identifica', 'Publicacao_Academica',
       'Projetos', 'Confirmacao_Intercambio'
]

# Mostrar os valores únicos de cada coluna
for coluna in colunas:
    print(f'{coluna}: {dados[coluna].unique()}')
# Out:
# Nome: ['Gabriel Rodrigues Freitas ' 'Arthur Rocha Cavalcante'
#  'Oziele Rodrigues de Oliveira ' 'Gilmar Thomaz Dantas Pereira da Silva'
#  'José Maria Soares ' 'Fabiana de Souza Silva' 'Otaciel da Silva RIbeiro'
#  'David Soares Carvalho ' 'Rafael Ribeiro ' 'Laura Kauanne da Silva '
#  'Monik Gomes ' 'Maria ivelise da Silva ' 'Edson Domingos da Silva '
#  'Edenilson Lima de Freitas' 'Pedro Henrique Amorim de Azevedo'
#  'Damaris dos Santos Tavares ' 'José Moreira Chacon'
#  'João Maria Floriano Silva Júnior ' 'Rayane Cristine Candido de lima '
#  'Fernanda Gomes do Nascimento ' 'Arthur Soares Lima'
#  'Júlia Ursulino Galvão' 'José Isac Souza da Costa'
#  'Adriana Euflazino da Silva' 'Leonarda soares de souza'
#  'Thiago Morais Cordeiro' 'Clara maria avelino Ribeiro '
#  'Lucas Emanoel da Silva Freitas' 'Luiz Felipe Silva de Oliveira '
#  'José Geovane de Oliveira Estevão ' 'Fabiana Avelino Da Silva'
#  'Matheus Fernando Leite' 'Walison Paulino de Oliveira '
# ...

# %% [markdown]
# ## Parte 2

# %%
lista = []
for trab in dados['Subareas_se_Identifica']:
    lista += trab.split(',')


lista_areas = pd.Series(lista)
lista_areas.groupby(lista_areas.values).count().sort_values(ascending=False)
# Out:
#  Desenvolvimento Web                             24
# Banco de Dados                                   10
#  Desenvolvimento Mobile                          10
# Desenvolvimento Web                              10
# Análise de Dados e Business Intelligence (BI)    10
# Outro                                             9
#  Redes de Computadores                            7
#  Gestão de Projetos de TI                         6
#  Segurança da Informação                          5
# Desenvolvimento Mobile                            5
#  Desenvolvimento Desktop                          4
#  Banco de Dados                                   3
#  Outro                                            3
#  Infraestrutura de TI                             3
# Redes de Computadores                             3
# Cloud Computing                                   1
# Desenvolvimento Desktop                           1
#  Cloud Computing                                  1
# ...

# %%
dados.groupby('Cidade')['Cidade'].count()
# Out:
# Cidade
# Arez                         1
# Baía Formosa/RN              8
# Canguaretama/RN             18
# Goianinha/RN                11
# Macaíba                      1
# Montanhas                    1
# Natal RN                     1
# Nova cruz                    1
# Pedro Velho/RN               3
# Senador Georgino Avelino     1
# São José de Mipibu/RN        2
# Tibau do Sul                 1
# Vila Flor                    1
# Name: Cidade, dtype: int64

# %%
dados.loc[dados['Cidade'].str.strip().isin(['Baia Formosa', 'Baía Formosa']), 'Cidade'] = 'Baía Formosa/RN'
dados.groupby('Cidade')['Cidade'].count()
# Out:
# Cidade
# Arez                         1
# Baía Formosa/RN              8
# Canguaretama/RN             18
# Goianinha/RN                11
# Macaíba                      1
# Montanhas                    1
# Natal RN                     1
# Nova cruz                    1
# Pedro Velho/RN               3
# Senador Georgino Avelino     1
# São José de Mipibu/RN        2
# Tibau do Sul                 1
# Vila Flor                    1
# Name: Cidade, dtype: int64

# %%
# dados[(dados.Cidade == 'Canguaretama-RN') | (dados.Cidade == 'Canguaretamam') | (dados.Cidade == 'Canguaretama') | (dados.Cidade == 'Canguaretama ')] = 'Canguaretama/RN'
# dados[(dados.Cidade == 'Canguaretama-RN') | (dados.Cidade == 'Canguaretamam') | (dados.Cidade == 'Canguaretama') | (dados.Cidade == 'Canguaretama ')] = 'Canguaretama/RN'
dados.loc[dados['Cidade'].str.strip().isin(['Canguaretama-RN', 'Canguaretamam', 'Canguaretama']), 'Cidade'] = 'Canguaretama/RN'
dados.groupby('Cidade')['Cidade'].count()
# Out:
# Cidade
# Arez                         1
# Baía Formosa/RN              8
# Canguaretama/RN             18
# Goianinha/RN                11
# Macaíba                      1
# Montanhas                    1
# Natal RN                     1
# Nova cruz                    1
# Pedro Velho/RN               3
# Senador Georgino Avelino     1
# São José de Mipibu/RN        2
# Tibau do Sul                 1
# Vila Flor                    1
# Name: Cidade, dtype: int64

# %%
dados.loc[dados['Cidade'].str.strip().isin(['Goaininha', 'Goianinha', 'Goianinha RN']), 'Cidade'] = 'Goianinha/RN'
dados.groupby('Cidade')['Cidade'].count()
# Out:
# Cidade
# Arez                         1
# Baía Formosa/RN              8
# Canguaretama/RN             18
# Goianinha/RN                11
# Macaíba                      1
# Montanhas                    1
# Natal RN                     1
# Nova cruz                    1
# Pedro Velho/RN               3
# Senador Georgino Avelino     1
# São José de Mipibu/RN        2
# Tibau do Sul                 1
# Vila Flor                    1
# Name: Cidade, dtype: int64

# %%
dados.loc[dados['Cidade'].str.strip().isin(['Pedro Velho', 'Pedro Velho']), 'Cidade'] = 'Pedro Velho/RN'
dados.groupby('Cidade')['Cidade'].count()
# Out:
# Cidade
# Arez                         1
# Baía Formosa/RN              8
# Canguaretama/RN             18
# Goianinha/RN                11
# Macaíba                      1
# Montanhas                    1
# Natal RN                     1
# Nova cruz                    1
# Pedro Velho/RN               3
# Senador Georgino Avelino     1
# São José de Mipibu/RN        2
# Tibau do Sul                 1
# Vila Flor                    1
# Name: Cidade, dtype: int64

# %%
dados.loc[dados['Cidade'].str.strip().isin(['São José de Mipibu', 'São josé de Mipibu']), 'Cidade'] = 'São José de Mipibu/RN'
dados.groupby('Cidade')['Cidade'].count()
# Out:
# Cidade
# Arez                         1
# Baía Formosa/RN              8
# Canguaretama/RN             18
# Goianinha/RN                11
# Macaíba                      1
# Montanhas                    1
# Natal RN                     1
# Nova cruz                    1
# Pedro Velho/RN               3
# Senador Georgino Avelino     1
# São José de Mipibu/RN        2
# Tibau do Sul                 1
# Vila Flor                    1
# Name: Cidade, dtype: int64

# %%
dados.groupby('Cidade')['Cidade'].count()
# Out:
# Cidade
# Arez                         1
# Baía Formosa/RN              8
# Canguaretama/RN             18
# Goianinha/RN                11
# Macaíba                      1
# Montanhas                    1
# Natal RN                     1
# Nova cruz                    1
# Pedro Velho/RN               3
# Senador Georgino Avelino     1
# São José de Mipibu/RN        2
# Tibau do Sul                 1
# Vila Flor                    1
# Name: Cidade, dtype: int64

# %%
dados
# Out:
#                                      Nome  Data_Nascimento            Turma  \
# 0                         Canguaretama/RN  Canguaretama/RN  Canguaretama/RN
# 1                 Arthur Rocha Cavalcante       03/08/1998         TSI 2021
# 2                         Canguaretama/RN  Canguaretama/RN  Canguaretama/RN
# 3   Gilmar Thomaz Dantas Pereira da Silva       08/06/2003         TSI 2022
# 4                      José Maria Soares        17/04/1998         TSI 2022
# 5                  Fabiana de Souza Silva       12/09/1997         TSI 2020
# 6                Otaciel da Silva RIbeiro       21/07/2003         TSI 2022
# 7                  David Soares Carvalho        09/02/2001         TSI 2022
# 8                         Rafael Ribeiro        05/01/2000         TSI 2020
# 9                 Laura Kauanne da Silva        03/05/2002         TSI 2020
# 10                        Canguaretama/RN  Canguaretama/RN  Canguaretama/RN
# ...
