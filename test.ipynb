# %%
import pandas as pd

# %%
# Criação de DataFrame
dados = {
    'Nome': ['Arthur', 'Edenilson', 'Pedro Lucas', 'Luiz Felipe'],
    'Idade': ['25', '45', '20', '20'],
    'Cidade': ['Baía Formosa', 'São José de Mipibu', 'Canguaretama', 'Canguaretama'],
    'Turma': ['TSI 2021.1', 'TSI 2021.1', 'TSI 2021.1', 'TSI 2021.1']
}

df_dados = pd.DataFrame(dados)
df_dados
# Out:
#           Nome Idade              Cidade       Turma
# 0       Arthur    25        Baía Formosa  TSI 2021.1
# 1    Edenilson    45  São José de Mipibu  TSI 2021.1
# 2  Pedro Lucas    20        Canguaretama  TSI 2021.1
# 3  Luiz Felipe    20        Canguaretama  TSI 2021.1

# %%
# Dados fictícios
dados = {
    'Nome completo': ['João Silva', 'Maria Oliveira', 'Carlos Santos'],
    'Data de nascimento': ['1995-03-10', '1998-08-22', '1993-05-15'],
    'Turma': ['A', 'B', 'C'],
    'Cidade': ['São Paulo', 'Rio de Janeiro', 'Belo Horizonte'],
    'A região em que mora': ['Sudeste', 'Sudeste', 'Sudeste'],
    'Ensino médio': ['Completo', 'Completo', 'Completo'],
    'Situação da Matrícula': ['Ativo', 'Ativo', 'Desistente'],
    'Semestres Cursando': [5, 6, 4],
    'Semestre Desistência': [None, None, 3],  # Preencha com valores reais, se aplicável
    'Modalidade estágio': ['Sim', 'Não', 'Sim'],
    'Satisfeito(a) com o estágio de TI': ['Sim', 'Não', 'Sim'],
    'Concluiu, começou ou continuou a trabalhar após o curso': ['Sim', 'Não', 'Sim'],
    'Modalidade Trabalho após o curso': ['Emprego fixo', 'Freelance', 'Emprego fixo'],
    'Área que Trabalhou/trabalha na TI': ['Desenvolvimento web', 'Suporte técnico', 'Redes'],
    'Áreas estágio': ['Desenvolvimento de software', 'Suporte técnico', 'Redes'],
    'Subáreas mais se identifica': ['Front-end', 'Help Desk', 'Segurança da Informação'],
    'Publicação acadêmica': ['Sim', 'Não', 'Não'],
    'Projetos': ['Projeto A', 'Projeto B', 'Projeto C'],
    'Confirmação de intercâmbio': ['Sim', 'Não', 'Não']
}

# Criando o DataFrame
df_alunos = pd.DataFrame(dados)

# Exibindo o DataFrame
df_alunos
# Out:
#     Nome completo Data de nascimento Turma          Cidade  \
# 0      João Silva         1995-03-10     A       São Paulo
# 1  Maria Oliveira         1998-08-22     B  Rio de Janeiro
# 2   Carlos Santos         1993-05-15     C  Belo Horizonte
#
#   A região em que mora Ensino médio Situação da Matrícula  Semestres Cursando  \
# 0              Sudeste     Completo                 Ativo                   5
# 1              Sudeste     Completo                 Ativo                   6
# 2              Sudeste     Completo            Desistente                   4
#
#    Semestre Desistência Modalidade estágio Satisfeito(a) com o estágio de TI  \
# 0                   NaN                Sim                               Sim
# 1                   NaN                Não                               Não
# 2                   3.0                Sim                               Sim
#
#   Concluiu, começou ou continuou a trabalhar após o curso  \
# ...

# %%
df_alunos = pd.DataFrame(dados)

df_alunos.rename(columns={'Nome': 'Nomecompleto'}, inplace=True)
df_alunos
# Out:
#     Nome completo Data de nascimento Turma          Cidade  \
# 0      João Silva         1995-03-10     A       São Paulo
# 1  Maria Oliveira         1998-08-22     B  Rio de Janeiro
# 2   Carlos Santos         1993-05-15     C  Belo Horizonte
#
#   A região em que mora Ensino médio Situação da Matrícula  Semestres Cursando  \
# 0              Sudeste     Completo                 Ativo                   5
# 1              Sudeste     Completo                 Ativo                   6
# 2              Sudeste     Completo            Desistente                   4
#
#    Semestre Desistência Modalidade estágio Satisfeito(a) com o estágio de TI  \
# 0                   NaN                Sim                               Sim
# 1                   NaN                Não                               Não
# 2                   3.0                Sim                               Sim
#
#   Concluiu, começou ou continuou a trabalhar após o curso  \
# ...
