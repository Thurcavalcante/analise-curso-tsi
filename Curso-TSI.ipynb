# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Carregando o dataset
df = pd.read_csv('alunos_tsi.csv')
df.head(5)
# Out:
#   Carimbo de data/hora                          Nome completo  \
# 0                  NaN             Gabriel Rodrigues Freitas
# 1                  NaN                Arthur Rocha Cavalcante
# 2                  NaN          Oziele Rodrigues de Oliveira
# 3                  NaN  Gilmar Thomaz Dantas Pereira da Silva
# 4                  NaN                     José Maria Soares
#
#   Data de nascimento     Turma           Cidade A regiao em que mora  \
# 0         13/12/2000  TSI 2020    Canguaretama                Urbana
# 1         03/08/1998  TSI 2021     Baía Formosa               Urbana
# 2         16/07/1999  TSI 2020    Canguaretama                 Rural
# 3         08/06/2003  TSI 2022     Baia Formosa               Urbana
# 4         17/04/1998  TSI 2022  Canguaretama/RN                Rural
#
#      Ensino medio              Situação da Matricula  \
# 0  Escola Pública  Está cursando com matrícula ativa
# 1  Escola Pública  Está cursando com matrícula ativa
# ...

# %%
# 1. Distribuição por Turma (Ano de Matrícula)
turma_counts = df['Turma'].value_counts()
turma_counts
# Out:
# Turma
# TSI 2021    16
# TSI 2020    12
# TSI 2023     9
# TSI 2022     6
# Name: count, dtype: int64

# %%
# Visualização da distribuição
plt.figure(figsize=(8, 6))
sns.barplot(x=turma_counts.index, y=turma_counts.values, palette='viridis')
plt.title('Distribuição de Alunos por Turma')
plt.xlabel('Turma')
plt.ylabel('Número de Alunos')
plt.show()
# Out:
# C:\Users\Arthur Cavalcante\AppData\Local\Temp\ipykernel_13908\2779918855.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=turma_counts.index, y=turma_counts.values, palette='viridis')

# %%
# 2. Distribuição por Cidade e Região
# Contagem de alunos por cidade
cidade_counts = df['Cidade'].value_counts()
ci
# Out:
# -------------------------------------
# NameErrorTraceback (most recent call last)
# Cell In[5], line 4
#       1 # 2. Distribuição por Cidade e Região
#       2 # Contagem de alunos por cidade
#       3 cidade_counts = df['Cidade'].value_counts()
# ----> 4 ci
#
# NameError: name 'ci' is not defined

# %%
# Visualização da distribuição por cidade
plt.figure(figsize=(12, 8))
sns.barplot(x=cidade_counts.values, y=cidade_counts.index, palette='plasma')
plt.title('Distribuição de Alunos por Cidade')
plt.xlabel('Número de Alunos')
plt.ylabel('Cidade')
plt.show()
# Out:
# C:\Users\Arthur Cavalcante\AppData\Local\Temp\ipykernel_13908\3352718643.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=cidade_counts.values, y=cidade_counts.index, palette='plasma')

# %%
# Contagem de alunos por região
regiao_counts = df['A regiao em que mora'].value_counts()
regiao_counts
# Out:
# A regiao em que mora
# Urbana    28
# Rural     15
# Name: count, dtype: int64

# %%
# Visualização da distribuição por região
plt.figure(figsize=(8, 6))
sns.barplot(x=regiao_counts.index, y=regiao_counts.values, palette='magma')
plt.title('Distribuição de Alunos por Região')
plt.xlabel('A regiao em que mora')
plt.ylabel('Número de Alunos')
plt.show()
# Out:
# C:\Users\Arthur Cavalcante\AppData\Local\Temp\ipykernel_13908\4030996331.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=regiao_counts.index, y=regiao_counts.values, palette='magma')

# %%
# 3. Situação Atual no Curso
situacao_counts = df['Situação da Matricula'].value_counts()
situacao_counts
# Out:
# Situação da Matricula
# Está cursando com matrícula ativa                     33
# Já concluiu                                            7
# Não está cursando e não está com a matrícula ativa     2
# Não está cursando mas está com a matrícula ativa       1
# Name: count, dtype: int64

# %%
# Visualização da distribuição da situação no curso
plt.figure(figsize=(10, 6))
sns.barplot(x=situacao_counts.index, y=situacao_counts.values, palette='rocket')
plt.title('Distribuição da Situação Atual no Curso')
plt.xlabel('Semestres Cursando')
plt.ylabel('Número de Alunos')
plt.show()
# Out:
# C:\Users\Arthur Cavalcante\AppData\Local\Temp\ipykernel_13908\1425899279.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=situacao_counts.index, y=situacao_counts.values, palette='rocket')

# %%
# 4. Trabalho Antes e Durante o Curso
trabalho_antes_curso_counts = df['Trabalho antes do curso'].value_counts()
trabalho_durante_curso_counts = df['Continuou trabalhando durante o curso'].value_counts()
t
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       2 trabalho_antes_curso_counts = df['Trabalho antes do curso'].value_counts()
#       3 trabalho_durante_curso_counts = df['Continuou trabalhando durante o curso'].value_counts()
# ----> 4 t
#
# NameError: name 't' is not defined

# %%
df.head(1)
# Out:
#   Carimbo de data/hora               Nome completo Data de nascimento  \
# 0                  NaN  Gabriel Rodrigues Freitas          13/12/2000
#
#       Turma         Cidade A regiao em que mora    Ensino medio  \
# 0  TSI 2020  Canguaretama                Urbana  Escola Pública
#
#                Situação da Matricula        Semestres Cursando  \
# 0  Está cursando com matrícula ativa  4º Semestre, 6º Semestre
#
#   Semestre Desistencia  ...            Modalidade estágio  \
# 0                  NaN  ...  Não estagiei durante o curso
#
#   Satisteito(a) com o estágio de TI  \
# 0                               Não
#
#   Concluiu, começou ou continuou a trabalhar apos o curso?  \
# 0                                                Não
#
#       Modalidade Trabalhao após o curso Area que Trabalhou/trabalha na TI  \
# 0  Não comecei a trabalhar após o curso                             Outro
#
#   Areas estagio Subáreas mais se identifica  Publicação acadêmica  \
# ...

# %%
# 6. Participação em Projetos Acadêmicos
projetos_counts = df['Projetos'].value_counts()
projetos_counts
# Out:
# Projetos
# Não                                                   18
# Sim, projeto de pesquisa                              14
# Sim, projeto de pesquisa, Sim, Projeto de extensão     8
# Sim, Projeto de extensão                               3
# Name: count, dtype: int64

# %%
# Visualização da participação em projetos acadêmicos
plt.figure(figsize=(8, 6))
sns.barplot(x=projetos_counts.index, y=projetos_counts.values, palette='YlGnBu')
plt.title('Participação em Projetos Acadêmicos')
plt.xlabel('projetos')
plt.ylabel('Número de Alunos')
plt.show()
# Out:
# C:\Users\Arthur Cavalcante\AppData\Local\Temp\ipykernel_13908\3211926569.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=projetos_counts.index, y=projetos_counts.values, palette='YlGnBu')

# %%
# 7. Intercâmbio
intercambio_counts = df['Confirmação de intercâmbio'].value_counts()
intercambio_counts
# Out:
# Confirmação de intercâmbio
# Não    42
# Sim     1
# Name: count, dtype: int64

# %%
# Visualização da participação em intercâmbio
plt.figure(figsize=(8, 6))
sns.barplot(x=intercambio_counts.index, y=intercambio_counts.values, palette='Oranges')
plt.title('Participação em Intercâmbio')
plt.xlabel('Confirmação de intercâmbio')
plt.ylabel('Número de Alunos')
plt.show()
# Out:
# C:\Users\Arthur Cavalcante\AppData\Local\Temp\ipykernel_13908\1534976157.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=intercambio_counts.index, y=intercambio_counts.values, palette='Oranges')

# %%
# 8. Publicações Acadêmicas
publicacoes_counts = df['Publicação acadêmica'].value_counts()
publicacoes_counts
# Out:
# Publicação acadêmica
# Não tive publicações                                                                                            32
# Artigo (resumo ou completo) em congresso                                                                         4
# Artigo (resumo ou completo) em congresso, Livro ou capítulo de livro                                             2
# Artigo (resumo ou completo) em congresso, Artigo (resumo ou completo) em revista, Livro ou capítulo de livro     2
# Livro ou capítulo de livro                                                                                       2
# Artigo (resumo ou completo) em revista                                                                           1
# Name: count, dtype: int64

# %%
 Visualização da participação em publicações acadêmicas
plt.figure(figsize=(8, 6))
sns.barplot(x=publicacoes_counts.index, y=publicacoes_counts.values, palette='PuBuGn')
plt.title('Participação em Publicações Acadêmicas')
plt.xlabel('Publicação acadêmica')
plt.ylabel('Número de Alunos')
plt.show()
# Out:
#   Cell In[22], line 1
#     Visualização da participação em publicações acadêmicas
#                  ^
# SyntaxError: invalid syntax
