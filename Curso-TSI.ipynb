# %%
# Imports

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('alunos_tsi.csv')
df.head(5)
# Out:
#   Carimbo de data/hora                          Nome completo  \
# 0                  NaN             Gabriel Rodrigues Freitas
# 1                  NaN                Arthur Rocha Cavalcante
# 2                  NaN          Oziele Rodrigues de Oliveira
# 3                  NaN  Gilmar Thomaz Dantas Pereira da Silva
# 4                  NaN                     José Maria Soares
#
#   Data de nascimento     Turma           Cidade A regiao em que mora  \
# 0         13/12/2000  TSI 2020    Canguaretama                Urbana
# 1         03/08/1998  TSI 2021     Baía Formosa               Urbana
# 2         16/07/1999  TSI 2020    Canguaretama                 Rural
# 3         08/06/2003  TSI 2022     Baia Formosa               Urbana
# 4         17/04/1998  TSI 2022  Canguaretama/RN                Rural
#
#      Ensino medio              Situação da Matricula  \
# 0  Escola Pública  Está cursando com matrícula ativa
# 1  Escola Pública  Está cursando com matrícula ativa
# ...

# %%
# Exemplo usando seaborn para histograma
sns.histplot(data=df, x='Data de nascimento', bins=20, kde=True)
plt.title('Distribuição por Idade dos Alunos')
plt.show()

# %%
df_dados = pd.read_csv('alunos_tsi.csv')
df_dados.head(5)
# Out:
#   Carimbo de data/hora                          Nome completo  \
# 0                  NaN             Gabriel Rodrigues Freitas
# 1                  NaN                Arthur Rocha Cavalcante
# 2                  NaN          Oziele Rodrigues de Oliveira
# 3                  NaN  Gilmar Thomaz Dantas Pereira da Silva
# 4                  NaN                     José Maria Soares
#
#   Data de nascimento     Turma           Cidade A regiao em que mora  \
# 0         13/12/2000  TSI 2020    Canguaretama                Urbana
# 1         03/08/1998  TSI 2021     Baía Formosa               Urbana
# 2         16/07/1999  TSI 2020    Canguaretama                 Rural
# 3         08/06/2003  TSI 2022     Baia Formosa               Urbana
# 4         17/04/1998  TSI 2022  Canguaretama/RN                Rural
#
#      Ensino medio              Situação da Matricula  \
# 0  Escola Pública  Está cursando com matrícula ativa
# 1  Escola Pública  Está cursando com matrícula ativa
# ...

# %%
df_alunos = pd.DataFrame(df_dados)

# Apagando a coluna "Carimbo de data/hora"
df_alunos = df_alunos.d
